# %%
import pandas as pd
import seaborn as sns
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
from bokeh.charts import Donut, show
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3cc347af-1329-4ec0-8d92-81c0f6df4bd5">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Introduction
# Hey there! My name is Katherine Larson and I joined on as a Data Scientist in July 2016, though I had been interning with the firm since 2014. Since my first internship with Booz Allen, it’s been embedded in my head that data is the key to everything. All the trends in the all the data hold meaning, but it’s up to us to discover what that meaning is through data science techniques. While I think I’ve mastered manipulating pandas dataframes, what I want more experience in is data visualization, particularly mapping. So, I searched the very popular Kaggle to find a dataset that had coordinates. I located a dataset that not only had coordinates, but also had dates. Dates within a dataset are incredibly vital because it allows us to track trends over time – after all everything is changing every day.
# The data was taken from the NTSB aviation accident database. It includes all aviation accidents reported in the United States, its territories and possessions, and in international waters. I plan on examining a variation of the 31 features included to consider what patterns tend to be prevalent during an accident.  The data contains accidents as recent as 2017 and as far back as 1962. Datasets involving accidents and fatalities are important for data scientists to investigate because with enough data, we may one day be able to prevent them.
#
# Data: https://www.kaggle.com/khsamaha/aviation-accident-database-synopses

# %%
data = pd.read_csv("AviationDataEnd2016UP.csv")

# %%
data[:5]
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20170103X43747            Accident      WPR17LA046  2017-01-03
# 1  20161230X55950            Accident      WPR17FA044  2016-12-29
# 2  20161229X93022            Accident      CEN17LA062  2016-12-27
# 3  20161227X80237            Accident      CEN17LA061  2016-12-27
# 4  20161226X80840            Accident      WPR17FA041  2016-12-26
#
#          Location        Country   Latitude   Longitude Airport.Code  \
# 0    Paradise, MT  United States        NaN         NaN          NaN
# 1       Dabob, WA  United States  47.823611 -122.790000          NaN
# 2    Piedmont, MO  United States        NaN         NaN          NaN
# 3  Farmington, MO  United States  37.761111  -90.428611          FAM
# 4      Fresno, CA  United States  36.844444 -119.870834          E79
#
#       Airport.Name Injury.Severity Aircraft.Damage Aircraft.Category  \
# 0              NaN       Non-Fatal     Substantial          Airplane
# 1              NaN        Fatal(4)     Substantial          Airplane
# 2              NaN       Non-Fatal     Substantial          Airplane
# 3  FARMINGTON RGNL       Non-Fatal     Substantial          Airplane
# 4  Sierra Sky Park        Fatal(2)       Destroyed          Airplane
#
#   Registration.Number                Make  Model Amateur.Built  \
# 0              N710XP   SOFTEX INVEST LLC  V-24L           Yes
# 1              N52388              CESSNA    182            No
# 2              N5499Z               PIPER   PA22            No
# 3              N918KS                MEAD  RV 8A           Yes
# 4              N176PA  PETRUS DAVID WAYNE    S90           Yes
#
#    Number.of.Engines    Engine.Type            FAR.Description Schedule  \
# 0                NaN  Reciprocating  Part 91: General Aviation      NaN
# 1                1.0  Reciprocating  Part 91: General Aviation      NaN
# 2                1.0  Reciprocating  Part 91: General Aviation      NaN
# 3                NaN            NaN  Part 91: General Aviation      NaN
# 4                NaN  Reciprocating  Part 91: General Aviation      NaN
#
#   Purpose.of.Flight Air.Carrier  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 0          Personal         NaN                   NaN                     2.0
# 1          Personal         NaN                   4.0                     NaN
# 2          Personal         NaN                   NaN                     NaN
# 3          Personal         NaN                   NaN                     NaN
# 4          Personal         NaN                   2.0                     NaN
#
#    Total.Minor.Injuries  Total.Uninjured Weather.Condition  \
# 0                   NaN              NaN               VMC
# 1                   NaN              NaN               VMC
# 2                   NaN              1.0               VMC
# 3                   1.0              1.0               VMC
# 4                   NaN              NaN               VMC
#
#   Broad.Phase.of.Flight Report.Status Publication.Date
# 0                CRUISE   Preliminary       05/01/2017
# 1                   NaN   Preliminary       05/01/2017
# 2               LANDING   Preliminary       03/01/2017
# 3               TAKEOFF   Preliminary       29/12/2016
# 4               TAKEOFF   Preliminary       05/01/2017

# %% [markdown]
# ## Initial Analysis

# %%
print("The total number of accidents included in the dataset are %d" % len(data))
# Out:
# The total number of accidents included in the dataset are 79293

# %% [markdown]
# **Upon first glance of the data it is very evident that not all fields are always reported for each accident. For the columns that seemed most likely to hold significance, I looked at the possible responses for that column as well as the total number of responses that the column actually had. **

# %%
print(data.columns)
# Out:
# Index([u'Event.Id', u'Investigation.Type', u'Accident.Number', u'Event.Date',
#        u'Location', u'Country', u'Latitude', u'Longitude', u'Airport.Code',
#        u'Airport.Name', u'Injury.Severity', u'Aircraft.Damage',
#        u'Aircraft.Category', u'Registration.Number', u'Make', u'Model',
#        u'Amateur.Built', u'Number.of.Engines', u'Engine.Type',
#        u'FAR.Description', u'Schedule', u'Purpose.of.Flight', u'Air.Carrier',
#        u'Total.Fatal.Injuries', u'Total.Serious.Injuries',
#        u'Total.Minor.Injuries', u'Total.Uninjured', u'Weather.Condition',
#        u'Broad.Phase.of.Flight', u'Report.Status', u'Publication.Date'],
#       dtype='object')

# %%
interesting_cols = ['Injury.Severity', 'Aircraft.Damage', 'Aircraft.Category', 'Amateur.Built', 'Number.of.Engines', 'FAR.Description', 'Weather.Condition', 'Broad.Phase.of.Flight']

for col in interesting_cols:
    data_sub = data.dropna(subset=[col])
    print(col)
    print("Possible Responses")
    print(str(pd.unique(data_sub[col])))
    print("Number of responses: " + str(len(data_sub)))
    print("-------------------------------------------")
# Out:
# Injury.Severity
# Possible Responses
# ['Non-Fatal' 'Fatal(4)' 'Fatal(2)' 'Fatal(3)' 'Fatal(1)' 'Incident'
#  'Unavailable' 'Fatal(6)' 'Fatal(5)' 'Fatal(8)' 'Fatal(16)' 'Fatal(66)'
#  'Fatal(7)' 'Fatal(62)' 'Fatal(23)' 'Fatal(10)' 'Fatal(9)' 'Fatal(224)'
#  'Fatal(150)' 'Fatal(43)' 'Fatal(162)' 'Fatal(58)' 'Fatal(295)' 'Fatal(11)'
#  'Fatal(239)' 'Fatal(33)' 'Fatal(50)' 'Fatal(14)' 'Fatal(21)' 'Fatal(19)'
#  'Fatal(153)' 'Fatal(127)' 'Fatal(28)' 'Fatal(77)' 'Fatal(12)' 'Fatal(42)'
#  'Fatal(157)' 'Fatal(158)' 'Fatal(103)' 'Fatal(89)' 'Fatal(90)'
#  'Fatal(152)' 'Fatal(228)' 'Fatal(17)' 'Fatal(13)' 'Fatal(24)' 'Fatal(88)'
#  'Fatal(65)' 'Fatal(154)' 'Fatal(30)' 'Fatal(20)' 'Fatal(40)' 'Fatal(57)'
#  'Fatal(199)' 'Fatal(114)' 'Fatal(102)' 'Fatal(96)' 'Fatal(49)'
#  'Fatal(124)' 'Fatal(113)' 'Fatal(107)' 'Fatal(117)' 'Fatal(145)'
#  'Fatal(45)' 'Fatal(160)' 'Fatal(121)' 'Fatal(15)' 'Fatal(104)' 'Fatal(25)'
#  'Fatal(55)' 'Fatal(46)' 'Fatal(141)' 'Fatal(115)' 'Fatal(75)' 'Fatal(71)'
#  'Fatal(206)' 'Fatal(138)' 'Fatal(92)' 'Fatal(26)' 'Fatal(265)'
#  'Fatal(118)' 'Fatal(44)' 'Fatal(64)' 'Fatal(18)' 'Fatal(83)' 'Fatal(143)'
#  'Fatal(60)' 'Fatal(131)' 'Fatal(169)' 'Fatal(217)' 'Fatal(80)'
#  'Fatal(229)' 'Fatal(87)' 'Fatal(52)' 'Fatal(97)' 'Fatal(35)' 'Fatal(29)'
#  'Fatal(125)' 'Fatal(349)' 'Fatal(34)' 'Fatal(70)' 'Fatal(230)'
#  'Fatal(110)' 'Fatal(123)' 'Fatal(189)' 'Fatal(72)' 'Fatal(54)' 'Fatal(68)'
#  'Fatal(132)' 'Fatal(37)' 'Fatal(56)' 'Fatal(47)' 'Fatal(27)' 'Fatal(73)'
#  'Fatal(111)' 'Fatal(174)' 'Fatal(144)' 'Fatal(270)' 'Fatal(156)'
#  'Fatal(82)' 'Fatal(256)' 'Fatal(31)' 'Fatal(135)' 'Fatal(78)']
# Number of responses: 79293
# -------------------------------------------
# Aircraft.Damage
# Possible Responses
# ['Substantial' 'Destroyed' 'Minor']
# Number of responses: 76883
# -------------------------------------------
# Aircraft.Category
# Possible Responses
# ['Airplane' 'Helicopter' 'Weight-Shift' 'Glider' 'Unknown' 'Balloon'
#  'Powered Parachute' 'Ultralight' 'Gyroplane' 'Gyrocraft' 'Powered-Lift'
#  'Rocket' 'Blimp']
# Number of responses: 22477
# -------------------------------------------
# Amateur.Built
# Possible Responses
# ['Yes' 'No']
# Number of responses: 78721
# -------------------------------------------
# Number.of.Engines
# Possible Responses
# [  1.   2.   0.   4.   3.  18.]
# Number of responses: 75175
# -------------------------------------------
# FAR.Description
# Possible Responses
# ['Part 91: General Aviation' 'Part 135: Air Taxi & Commuter'
#  'Public Aircraft' 'Part 121: Air Carrier' 'Unknown'
#  'Non-U.S., Non-Commercial' 'Part 137: Agricultural' 'Non-U.S., Commercial'
#  'Part 103: Ultralight' 'Part 133: Rotorcraft Ext. Load' 'Public Use'
#  'Part 129: Foreign' 'Armed Forces' 'Part 437: Commercial Space Flight'
#  'Part 91 Subpart K: Fractional' 'Part 125: 20+ Pax,6000+ lbs'
#  'Part 91F: Special Flt Ops.']
# Number of responses: 22334
# -------------------------------------------
# Weather.Condition
# Possible Responses
# ['VMC' 'IMC' 'UNK']
# Number of responses: 77136
# -------------------------------------------
# Broad.Phase.of.Flight
# Possible Responses
# ['CRUISE' 'LANDING' 'TAKEOFF' 'DESCENT' 'APPROACH' 'OTHER' 'TAXI'
#  'GO-AROUND' 'MANEUVERING' 'UNKNOWN' 'STANDING' 'CLIMB']
# Number of responses: 73239
# -------------------------------------------

# %% [markdown]
# **The total number of responses for each column displays the amount of data lost if I were to take certain subsets. For example, if I wanted to look at the Aircraft Category, I would realize that I only have 22,477 responses for the 79,293 total accidents. However, a field such as weather condition has 77,136 responses which gives a better representation of the entire dataset.
# **

# %% [markdown]
# ## Data Cleanup

# %%
# Separating the date column into year, month, day
data['year'], data['month'], data['day'] = zip(*data['Event.Date'].map(lambda x: str(x).split('-')))

# %%
# Changing the fatal column to 'Non-Fatal', 'None', 'Fatal', or 'Unknown', and adding a 'Fatal_Count' in a separate column
import re
import numpy as np

fatal_counts = []
fatal_bools = []

for i in range(len(data)):
    fatal_resp = data.iloc[i]['Injury.Severity']
    if str(fatal_resp) == 'Non-Fatal':
        fatal_counts.append(0)
        fatal_bools.append("None")
    elif fatal_resp is not None:
        num = re.sub(r'\D', "", str(fatal_resp))
        if num == "":
            fatal_counts.append(np.nan)
            fatal_bools.append("Unknown")
        else:
            fatal_counts.append(int(num))
            fatal_bools.append("Fatal")
    else:
        fatal_counts.append(np.nan)
        fatal_bools.append("Unknown")
        
data['Fatal_Counts'] = fatal_counts
data['Fatal_Bool'] = fatal_bools

# %%
# New cleaned up data
data[:5]
# Out:
#           Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20170103X43747            Accident      WPR17LA046  2017-01-03
# 1  20161230X55950            Accident      WPR17FA044  2016-12-29
# 2  20161229X93022            Accident      CEN17LA062  2016-12-27
# 3  20161227X80237            Accident      CEN17LA061  2016-12-27
# 4  20161226X80840            Accident      WPR17FA041  2016-12-26
#
#          Location        Country   Latitude   Longitude Airport.Code  \
# 0    Paradise, MT  United States        NaN         NaN          NaN
# 1       Dabob, WA  United States  47.823611 -122.790000          NaN
# 2    Piedmont, MO  United States        NaN         NaN          NaN
# 3  Farmington, MO  United States  37.761111  -90.428611          FAM
# 4      Fresno, CA  United States  36.844444 -119.870834          E79
#
#       Airport.Name Injury.Severity Aircraft.Damage Aircraft.Category  \
# 0              NaN       Non-Fatal     Substantial          Airplane
# 1              NaN        Fatal(4)     Substantial          Airplane
# 2              NaN       Non-Fatal     Substantial          Airplane
# 3  FARMINGTON RGNL       Non-Fatal     Substantial          Airplane
# 4  Sierra Sky Park        Fatal(2)       Destroyed          Airplane
#
#   Registration.Number                Make  Model Amateur.Built  \
# 0              N710XP   SOFTEX INVEST LLC  V-24L           Yes
# 1              N52388              CESSNA    182            No
# 2              N5499Z               PIPER   PA22            No
# 3              N918KS                MEAD  RV 8A           Yes
# 4              N176PA  PETRUS DAVID WAYNE    S90           Yes
#
#    Number.of.Engines    Engine.Type            FAR.Description Schedule  \
# 0                NaN  Reciprocating  Part 91: General Aviation      NaN
# 1                1.0  Reciprocating  Part 91: General Aviation      NaN
# 2                1.0  Reciprocating  Part 91: General Aviation      NaN
# 3                NaN            NaN  Part 91: General Aviation      NaN
# 4                NaN  Reciprocating  Part 91: General Aviation      NaN
#
#   Purpose.of.Flight Air.Carrier  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 0          Personal         NaN                   NaN                     2.0
# 1          Personal         NaN                   4.0                     NaN
# 2          Personal         NaN                   NaN                     NaN
# 3          Personal         NaN                   NaN                     NaN
# 4          Personal         NaN                   2.0                     NaN
#
#    Total.Minor.Injuries  Total.Uninjured Weather.Condition  \
# 0                   NaN              NaN               VMC
# 1                   NaN              NaN               VMC
# 2                   NaN              1.0               VMC
# 3                   1.0              1.0               VMC
# 4                   NaN              NaN               VMC
#
#   Broad.Phase.of.Flight Report.Status Publication.Date  year month day  \
# 0                CRUISE   Preliminary       05/01/2017  2017    01  03
# 1                   NaN   Preliminary       05/01/2017  2016    12  29
# 2               LANDING   Preliminary       03/01/2017  2016    12  27
# 3               TAKEOFF   Preliminary       29/12/2016  2016    12  27
# 4               TAKEOFF   Preliminary       05/01/2017  2016    12  26
#
#    Fatal_Counts Fatal_Bool
# 0           0.0       None
# 1           4.0      Fatal
# 2           0.0       None
# 3           0.0       None
# 4           2.0      Fatal

# %%
len(data[data['Fatal_Counts'] > 0])
# Out:
# 15873

# %% [markdown]
# ** There are 15,873 accidents that had at least one fatality**

# %% [markdown]
# ## Analysis

# %%
from bokeh.charts import HeatMap, output_file, show
from bokeh.charts import HeatMap, bins, output_file, show
from bokeh.layouts import column, gridplot

# %% [markdown]
# **Using Bokeh, I am going to create some visualizations to see what patterns are associated with fatal aircraft accidents. I am going to take a subset of the data with some features I think would yield intersting results, while also keeping in mind how these trends may be changing over time. **

# %%
# Features to consider
features = ['Location', 'Country', 'Latitude', 'Longitude', 'Aircraft.Damage', 'Make', 'Model', 'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description', 'Purpose.of.Flight', 'Total.Uninjured', 'Weather.Condition', 'Broad.Phase.of.Flight', 'year', 'month', 'Fatal_Counts', 'Fatal_Bool']

# %%
# Taking the subset
my_data = data[features]

# %%
# Function to create heatmap
def heatmap(df, category):
    temp = df[[category, 'year', 'Fatal_Counts']]
    temp = temp.dropna()
    temp = temp[temp['Fatal_Counts'] > 0]
    years = []
    descs = []
    fat_sum = []

    for k,g in temp.groupby(['year', category]):
        (year, desc) = k
        sum_fatal = sum(g['Fatal_Counts'])
        years.append(year)
        descs.append(desc)
        fat_sum.append(sum_fatal)

    dict_to_plot = {
        'year':years,
        category:descs,
        'fatal':fat_sum
    }
    
    print (len(years))
    return dict_to_plot

# %%
# Fatalities By Description
print("Accidents with at least one fatality for FAR.Description")
desc_map = HeatMap(heatmap(my_data,'FAR.Description'), y='year', x='FAR.Description', values='fatal', stat=None)
show(desc_map)

# Fatalities By Weather Condition
print("Accidents with at least one fatality for Weather Condition")
weather_map = HeatMap(heatmap(my_data,'Weather.Condition'), y='year', x='Weather.Condition', values='fatal', stat=None)
show(weather_map)

# Fatalities By Make
print("Accidents with at least one fatality Phase of Flight")
phase_map = HeatMap(heatmap(my_data, 'Broad.Phase.of.Flight'), y='year', x='Broad.Phase.of.Flight', values ='fatal', stat=None)
show(phase_map)

# Fatalities By Purpose
print("Accidents with at least one fatality for Purpose")
purpose_map = HeatMap(heatmap(my_data, 'Purpose.of.Flight'), y='year', x='Purpose.of.Flight', values ='fatal', stat=None)
show(purpose_map)

# Aircraft Damage
print("Accidents with at least one fatality for Aircraft Damage")
damage_map = HeatMap(heatmap(my_data, 'Aircraft.Damage'), y='year', x='Aircraft.Damage', values ='fatal', stat=None)
show(damage_map)
# Out:
# Accidents with at least one fatality for FAR.Description
# 165
#     <div class="bk-root">
#         <div class="plotdiv" id="aed44ab3-005d-4810-9cae-f9a0aee29ac9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aed44ab3-005d-4810-9cae-f9a0aee29ac9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aed44ab3-005d-4810-9cae-f9a0aee29ac9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"348bd0bc-9091-496e-921d-7085f524040a":{"roots":{"references":[{"attributes":{},"id":"8ca57624-afcc-446e-a78c-ac3090b9897d","type":"CategoricalTicker"},{"attributes":{"dilate":true,"fill_color":{"value":"#08519c"},"height":{"units":"data","value":0.95},"line_color":{"value":"#08519c"},"width":{"units":"data","value":0.95},"x":{"field":"x"},"y":{"field":"y"}},"id":
' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3707871e-1647-4ede-9001-feeba076a532":{"roots":{"references":[{"attributes":{"axis_label":"year","formatter":{"id":"15ac83db-5f1a-47f0-aba7-fe8cb776bb8b","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"ada12d76-e091-4720-aa4b-1798488e5fcc","subtype":"Chart","type":"Plot"},"ticker":{"id":"e7340e96-4f0f-4e5e-b1b9-839c28246531","type":"CategoricalTicker"}},"id":"0877a454-7bb1-47fa-ab2c-4fcfa393d60a","type":"CategoricalAxis"},{"attributes":{},"id":"756f273e-a14f-4584-873d-9dd6df29ddf7","type":"ToolEvents"},{"attributes":{"dilate":true,"fill_color":{"value":"#6baed6"},"height":{"units":"data","value":0.95},"line_color":{"value":"#6baed6"},"width":{"units":"data","value":0.95},"x":{"field":"x"},"y":{"field":"y"}},"id":"c5c58ed7-c1be-41bd-af49-0f8992e77f3a","type":"Rect"},{"attributes":{"data_source":{"id":"7f066d99-f261-421f-87ed-8f65b01303ee","type":"ColumnDataSource"},"glyph":{"id":"b600a46f-62d8-4c0c-b4d8-c7b7eb4b8fc7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"edd8fe98-41fe-4b17-ad5e-e95cf3050b78","type":"GlyphRenderer"},{"attributes":{"axis_label":"Weather.Condition","formatter":{"id":"4d80671f-39e5-481e-8358-f8f085cd4a5a","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"ada12d76-e091-4720-aa4b-1798488e5fcc","subtype":"Chart","type":"Plot"},"ticker":{"id":"ead884de-2de2-411c-9c4b-5bf005e7dc0f","type":"CategoricalTicker"}},"id":"5509f79c-176f-486b-a437-15004ae40344","type":"CategoricalAxis"},{"attributes":{"dilate":true,"fill_color":{"value":"#08519c"},"height":{"units":"data","value":0.95},"line_color":{"value":"#08519c"},"width":{"units":"data","value":0.95},"x":{"field":"x"},"y":{"field":"y"}},"id":"40941a13-dabc-432f-beec-f85113644b41","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","x","values"],"data":{"chart_index":[{"fatal":"(1141, 1369]"}],"fatal":["(1141, 1369]"],"values":[1369.0],"x":["VMC"],"y":["1996"]}},"id":"1afc7e8c-c1cf-46b8-a63d-bb7e6c4b5461","type":"ColumnDataSource"},{"attributes":{"dilate":true,"fill_color":{"value":"#eff3ff"},"height":{"units":"data","value":0.95},"line_color":{"value":"#eff3ff"},"width":{"units":"data","value":0.95},"x":{"field":"x"},"y":{"field":"y"}},"id":"d0d77d52-c01a-4a9f-ad50-9ce785aa5c59","type":"Rect"},{"attributes":{"callback":null,"column_names":["y","x","values"],"data":{"chart_index":[{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"},{"fatal":"(457, 685]"}],"fatal":["(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]","(457, 685]"],"values":[626.0,676.0,486.0,574.0,576.0,484.0,578.0,495.0,463.0,602.0,642.0,606.0,540.0,586.0,486.0,463.0],"x":["VMC","VMC","IMC","VMC","VMC","UNK","VMC","IMC","IMC","VMC","VMC","VMC","VMC","VMC","VMC","VMC"],"y":["1988","1990","1992","1993","1997","1998","1998","2000","2001","2002","2004","2006","2007","2008","2009","2010"]}},"id":"88f4055f-3cf8-48fb-8d8d-3cf03891fc45","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":null},"id":"1f7b39e2-5cd9-4764-95fb-ad1c0ae3606f","type":"Title"},{"attributes":{"data_source":{"id":"1afc7e8c-c1cf-46b8-a63d-bb7e6c4b5461","type":"ColumnDataSource"},"glyph":{"id":"40941a13-dabc-432f-beec-f85113644b41","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4a30ff2c-bd9e-49fc-94eb-eef285601e97","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ada12d76-e091-4720-aa4b-1798488e5fcc","subtype":"Chart","type":"Plot"}},"id":"9e4aa189-cefc-43be-8494-ddebce75cee0","t ...
# Accidents with at least one fatality Phase of Flight
# 401
#     <div class="bk-root">
#         <div class="plotdiv" id="651e2e14-fec2-4539-8eeb-58189751996b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById
},"width":{"units":"data","value":0.95},"x":{"field":"x"},"y":{"field":"y"}},"id":"f36153b7-a762-44fe-acd4-bd1cee840f13","type":"Rect"},{"attributes":{"callback":null,"factors":["CRUISE","UNKNOWN","APPROACH","CLIMB","DESCENT","GO-AROUND","LANDING","MANEUVERING","OTHER","STAN ...
# Accidents with at least one fatality for Purpose
# 495
#     <div class="bk-root">
#         <div class="plotdiv" id="d10999e4-8727-4926-9c14-29b1c5eff352"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d10999e4-8727-4926-9c14-29b1c5eff352");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd10999e4-8727-4926-9c14-29b1c5eff352' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"44a72647-f9f9-456c-baf0-320a510fe79a":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a72ef9fc-a0d7-4e61-af81-69d8bc5a52f5","type":"PanTool"},{"id":"3b5dc12d-4c9c-49f9-ab41-39d250d8d209","type":"WheelZoomTool"},{"id":"868e10c6-1241-4c56-b888-da69900e9fa9","type":"BoxZoomTool"},{"id":"e4f699ae-e5ba-4a4f-9aaa-d120d6a571eb","type":"SaveTool"},{"id":"f2032121-09c8-4cc9-b88b-ed65c1544682","type":"ResetTool"},{"id":"17639f12-ec83-42b1-9254-23374769fe16","type":"HelpTool"}]},"id":"fd06a746-c4cd-4934-baa9-e97d0a8bba82","type":"Toolbar"},{"attributes":{},"id":"f602f5dc-2801-47b2-8757-dbee33900429","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["y","x","values"],"data":{"chart_index":[{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"},{"fatal":"(201, 401]"}],"fatal":["(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]","(201, 401]"],"values":[231.0,397.0,206.0,270.0,374.0,392.0,379.0,370.0,377.0,296.0,327.0,342.0,267.0],"x":["Unknown","Unknown","Unknown","Unknown","Unknown","Personal","Personal","Personal","Personal","Personal","Personal","Personal","Personal"],"y":["1986","1988","1990","1991","1992","1999","2008","2010","2012","2013","2014","2015","2016"]}},"id":"88d31763-5623-4fc1-92a7-9b0ed2f1398a","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x","values"],"data":{"chart_index":[{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"},{"fatal":"(401, 601]"}],"fatal":["(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]","(401, 601]"],"values":[446.0,575.0,407.0,590.0,538.0,521.0,560.0,497.0,483.0,468.0,502.0,481.0,427.0,453.0,453.0,529.0,456.0,410.0,450.0,498.0,433.0,488.0,443.0,428.0,416.0,409.0],"x":["Unknown","Personal","Unknown","Personal","Personal","Personal","Personal","Personal","Personal","Unknown","Personal","Unknown","Personal","Personal","Personal","Unknown","Personal","Personal","Personal","Personal","Personal","Personal","Personal","Personal","Personal","Personal"],"y":["1982","1987","1987","1988","1989","1990","1991","1993","1994","1994","1995","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2009","2011"]}},"id":"05419473-0a79-47c2-993d-2180c0f9d7d9","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x","values"],"data":{"chart_index":[{"fatal":"(601, 801]"},{"fatal":"(601, 801]"},{"fatal":"(601, 801]"},{"fatal":"(601, 801]"},{"fatal":"(601, 801]"},{"fatal":"(601, 801]"},{"fatal":"(601, 801]"},{"fatal":"(601, 801]"}],"fatal":["(601, 801]","(601, 801]","(601, 801]","(601, 801]","(601, 801]","(601, 801]","(601, 801]","(601, 801]"],"values":[773.0,659.0,680.0,692.0,727.0,634.0,618.0,665.0],"x":["Personal","Personal","Unknown","Personal","Unknown","Personal","Unknown","Unknown"],"y":["1984","1985", ...
# Accidents with at least one fatality for Aircraft Damage
# 110
#     <div class="bk-root">
#         <div class="plotdiv" id="6db842ca-e5e6-44e7-b67c-b774dca7cbec"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed","Destroyed"],"y":["1983","1984","1986","1988","1990","1991","1992","1994","1995","1999","2003","2006","2007","2008","2014"]}},"id":"e82316fb-13bf-4482-b765-4eddb0737eee","type":"ColumnDataSource"},{"attributes":{"dilate":true,"fill_color":{"value":"#3182bd"},"height":{"units":"data","value":0.95},"line_color":{"value":"#3182bd"},"width":{"units":"data","value":0.95},"x":{"field":"x"},"y":{"field":"y"}},"id":"10894a69-65db-43d ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %% [markdown]
# ** These graphs only took into consideration flights which had at least one fatality. For most of the graphs, at least one column is definitively darker than the rest, meaning more fatalities occur during those circumstances. **
#
# ** For example, in Weather Condition, most accidents with a fatality occurred when the weather was ‘VMC’. So, I went back to the possible responses for weather. These responses include: VMC, IMC, or UNK. After some research with the NTSB database, I learned that VMC represents “weather conditions in which pilots have sufficient visibility to fly the aircraft maintaining visual separation from terrain and other aircraft”, while IMC represents, “weather conditions that require pilots to fly primarily by reference to instruments, and therefore under instrument flight rules (IFR), rather than by outside visual references under visual flight rules”. Meaning, over the years it has been consistent that most accidents with fatalities occur when the pilot has full control of the aircraft rather than when the pilot is relying on the plane’s instruments. **
#
# ** When considering phase of flight, more than one column is visibly darker than the rest, with ‘cruise’ standing out the most by just a bit. “Cruise” signifies the phase of flight that occurs between ascent and descent, the phase that the plane is in for the majority of the flight. The remaining visibly darker columns include approach, maneuvering, and takeoff, which are three of the main parts of flight. **
#
# ** Expectedly, most aircrafts that have fatal accidents are those where the aircraft gets destroyed. **

# %%
# Function to calculate the total accidents in a category over time
def sum_over_time(df, category):
    totals = []
    keys = []
    years = []
    
    for k, g in df.groupby(['year', category]):
        (yr, cat) = k
        totals.append(len(g))
        keys.append(cat)
        years.append(yr)
        
    dict_to_plot = {
        category : keys,
        'Total': totals,
        'Year': years
    }
    
    return dict_to_plot

# %%
# Total Over time
t = sum_over_time(my_data, 'Fatal_Bool')

# %%
# Tracking fatalities over time
from bokeh.charts import Line, show, output_file

x = t['Year']

t_df = pd.DataFrame(t)

p = figure(plot_width=800, plot_height=800, title ="Number of Accidents Reported")

# Fatal
fat = t_df[t_df['Fatal_Bool'] == 'Fatal']

# Unknown
uk = t_df[t_df['Fatal_Bool'] == 'Unknown']

# Nonfatal
nonfat = t_df[t_df['Fatal_Bool'] == 'None']

p.line(fat['Year'], fat['Total'] , legend="Fatal",
       line_color="red")

p.line(uk['Year'], uk['Total'] , legend="Not Reported",
       line_color="navy")

p.line(nonfat['Year'], nonfat['Total'] , legend="Not Fatal",
       line_color="green")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0148db7f-75c0-4adf-a35c-cdaeae9fce35"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0148db7f-75c0-4adf-a35c-cdaeae9fce35");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0148db7f-75c0-4adf-a35c-cdaeae9fce35' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5b2ff531-2357-418d-b1d0-17cafd5414d7":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b7d2694c-2311-4dfc-ab06-6ea223d8fc51","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"],"y":[2819,2759,2695,2428,2264,2206,2083,1959,1936,1891,1775,1786,1741,1774,1696,1654,1699,1732,1680,1565,1528,1564,1443,1509,1334,1511,1419,1326,1281,1329,1330,1104,1074,1108,1022,1]}},"id":"57d16b20-eeb4-4353-840d-b3477dac90ac","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"022cec5a-2ba5-4459-bc68-a217080ce9b3","type":"LinearAxis"}],"left":[{"id":"9d990ac0-9be9-46a7-a79a-9fe75248892d","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"022cec5a-2ba5-4459-bc68-a217080ce9b3","type":"LinearAxis"},{"id":"3f39cdf1-101b-49db-8554-ff91dbee0088","type":"Grid"},{"id":"9d990ac0-9be9-46a7-a79a-9fe75248892d","type":"LinearAxis"},{"id":"3c76b548-1461-4626-8a83-e3b82a1d6f6d","type":"Grid"},{"id":"36620111-e88b-4a35-a837-2262441a75f6","type":"BoxAnnotation"},{"id":"be6b63e9-5301-42c9-8b0f-4e5d825da3f7","type":"Legend"},{"id":"3e9b4b99-f1d9-4ec7-9134-cb17f933893d","type":"GlyphRenderer"},{"id":"3af42a91-5804-418f-8168-d7bb2788166e","type":"GlyphRenderer"},{"id":"a19f84f8-e9e6-45ab-abae-8aaf3e02daff","type":"GlyphRenderer"}],"title":{"id":"e60aa2f2-4865-4e49-a592-fe98a7f533d9","type":"Title"},"tool_events":{"id":"8c8afd57-cb90-4310-9e87-d5c63e79d57c","type":"ToolEvents"},"toolbar":{"id":"8d0b73b0-1801-4b7f-b9f5-ba4e2fd64335","type":"Toolbar"},"x_range":{"id":"9a331ac9-9c51-4e6f-9ea2-ba48a823ee6c","type":"DataRange1d"},"y_range":{"id":"91e24f4c-b054-4f95-a162-fe60eb978dce","type":"DataRange1d"}},"id":"7698618e-9f81-4bf2-96fe-bd046fee250d","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1bdb429e-654f-4d25-b725-9a28de40bd7a","type":"Line"},{"attributes":{},"id":"a5e1996c-1f63-459e-9301-1df2db5a807f","type":"BasicTicker"},{"attributes":{"plot":{"id":"7698618e-9f81-4bf2-96fe-bd046fee250d","subtype":"Figure","type":"Plot"}},"id":"f7724901-20c5-4965-a55a-9eae30511a1d","type":"ResetTool"},{"attributes":{"plot":null,"text":"Number of Accidents Reported"},"id":"e60aa2f2-4865-4e49-a592-fe98a7f533d9","type":"Title"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9614c0d4-09b4-4fac-b941-6805500ea530","type":"Line"},{"attributes":{"formatter":{"id":"a48413d3-719b-4919-9e9d-b9cb1a9469bd","type":"BasicTickFormatter"},"plot":{"id":"7698618e-9f81-4bf2-96fe-bd046fee250d","subtype":"Figure","type":"Plot"},"ticker":{"id":"1e4d78ad-97f7-49f9-86fa-399b29b774ac","type":"BasicTicker"}},"id":"022cec5a-2ba5-4459-bc68-a217080ce9b3","type":"LinearAxis"},{"attributes":{},"id":"8c8afd57-cb90-4310-9e87-d5c63e79d57c","type":"ToolEvents"},{"attributes":{"line_color":{"value":"navy"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d8d709fd-a8ff-47a3-bf12-8d9432d2ee60","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016"],"y":[119,137,133,100,89,116,137,88,69,72,69,80,54,68,63,81,92,64,84,78,68,72,83,87,101,113,125,114,168,146,136,107,102,109,71]}},"id":"06ce626d-ac60-45d5-8d1f-85bd335e361e","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d5c82894-50b5-4088-a09f-f2a3 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[18]</strong>&gt;</code></p>

# %% [markdown]
# ** Following the heat maps, I was interested in seeing if fatalities or accidents in general tend to be decreasing over the years. With the vast improvement in technology, I would expect that aircrafts are getting safer each day. The number of accidents overall is definitely decreasing, however the number of accidents that have at least one fatality is not decreasing as rapidly, but it is decreasing. Disclaimer: graph appears to drop suddenly, but that is only due to the fact that 2017 just started! **
#
# ** It seemed curious as to why there was such a jump in the 1980's. I decided to sort the accidents by their year to inspect the accidents with the earliest years. **

# %%
my_data.sort_values(by=['year'])[:15]
# Out:
#                   Location        Country   Latitude  Longitude  \
# 79292      MOOSE CREEK, ID  United States        NaN        NaN
# 79291       BRIDGEPORT, CA  United States        NaN        NaN
# 79290        Saltville, VA  United States  36.922223 -81.878056
# 79289           EUREKA, CA  United States        NaN        NaN
# 79288           Canton, OH  United States        NaN        NaN
# 79287           COTTON, MN  United States        NaN        NaN
# 76898        ANCHORAGE, AK  United States        NaN        NaN
# 76897      EAGLE RIVER, AK  United States        NaN        NaN
# 76896         PLYMOUTH, MI  United States        NaN        NaN
# 76895          DURANGO, CO  United States        NaN        NaN
# 76894             YUMA, CO  United States        NaN        NaN
# 76893  15MI. NE OF CHR, CO  United States        NaN        NaN
# 76892          EL PASO, TX  United States        NaN        NaN
# 76891       BUENA PARK, CA  United States        NaN        NaN
# 76890      GAINESVILLE, FL  United States        NaN        NaN
#
#       Aircraft.Damage        Make         Model Amateur.Built  \
# 79292       Destroyed     STINSON         108-3            No
# 79291       Destroyed       PIPER      PA24-180            No
# 79290       Destroyed      Cessna          172M            No
# 79289       Destroyed    Rockwell           112            No
# 79288       Destroyed      Cessna           501            No
# 79287       Destroyed      CESSNA           180            No
# 76898     Substantial      CESSNA           336            No
# 76897     Substantial       PIPER     PA-38-112            No
# 76896     Substantial  DRAGON FLY           NaN           Yes
# 76895     Substantial      CESSNA          172N            No
# 76894     Substantial    BELLANCA         7GCBC            No
# 76893       Destroyed       PIPER  PA-28RT-201T            No
# 76892           Minor      CESSNA          421B            No
# 76891     Substantial      CESSNA         T210L            No
# 76890     Substantial      CESSNA           210            No
#
#        Number.of.Engines    Engine.Type            FAR.Description  \
# 79292                1.0  Reciprocating                        NaN
# 79291                1.0  Reciprocating                        NaN
# 79290                1.0  Reciprocating                        NaN
# 79289                1.0  Reciprocating                        NaN
# 79288                NaN            NaN                        NaN
# 79287                1.0  Reciprocating                        NaN
# 76898                2.0  Reciprocating  Part 91: General Aviation
# 76897                1.0  Reciprocating  Part 91: General Aviation
# 76896                1.0  Reciprocating  Part 91: General Aviation
# 76895                1.0  Reciprocating  Part 91: General Aviation
# 76894                1.0  Reciprocating  Part 91: General Aviation
# 76893                1.0  Reciprocating  Part 91: General Aviation
# 76892                2.0     Turbo Prop  Part 91: General Aviation
# 76891                1.0  Reciprocating  Part 91: General Aviation
# 76890                1.0  Reciprocating  Part 91: General Aviation
#
#       Purpose.of.Flight  Total.Uninjured Weather.Condition  \
# 79292          Personal              0.0               UNK
# 79291          Personal              0.0               UNK
# 79290          Personal              NaN               IMC
# 79289          Personal              0.0               IMC
# 79288          Personal              NaN               VMC
# 79287          Personal              0.0               IMC
# 76898          Business              1.0               VMC
# 76897          Personal              2.0               VMC
# 76896          Personal              1.0               VMC
# 76895     Instructional              1.0               VMC
# 76894          Personal              1.0               VMC
# 76893          Personal              1.0               VMC
# 76892          Business              0.0               VMC
# 76891          Personal              1.0               VMC
# 76890          Personal              0.0               VMC
#
#       Broad.Phase.of.Flight  year month  Fatal_Counts Fatal_Bool
# 79292                CRUISE  1948    10           2.0      Fatal
# 79291               UNKNOWN  1962    07           4.0      Fatal
# 79290                CRUISE  1974    08           3.0      Fatal
# 79289                CRUISE  1977    06           2.0      Fatal
# 79288              APPROACH  1979    08           1.0      Fatal
# 79287               UNKNOWN  1981    08           4.0      Fatal
# 76898               LANDING  1982    08           0.0       None
# 76897           MANEUVERING  1982    08           0.0       None
# 76896               LANDING  1982    08           0.0       None
# 76895               LANDING  1982    08           0.0       None
# 76894               LANDING  1982    08           0.0       None
# 76893                CRUISE  1982    08           0.0       None
# 76892               DESCENT  1982    08           NaN    Unknown
# 76891               TAKEOFF  1982    08           0.0       None
# 76890                CRUISE  1982    08           0.0       None

# %% [markdown]
# **After reviewing the dataframe, I can see that the earliest accidents reported were all personal flights, with only 5 flights taken into consideration between 1948 - 1981. It would be expected that the accidents reported jump as the commercial aviation industry grew, so the jump in the data is not alarming. **

# %% [markdown]
# ## Map

# %%
import folium

# %% [markdown]
# **Now that I have an idea of trends over time I wanted to see if there were certain regions which had the tendency to have more accidents. There were too many accidents to map on folium, so I took a subset of those accidents reported in 2016. Those with a red marker indicate that the accident had at least one fatality, while a green marker represents that there were no fatalities. **

# %%
subset_data = my_data[['year', 'month', 'Latitude', 'Longitude', 'Aircraft.Damage', 'Fatal_Bool', 'Fatal_Counts']]
subset_data.dropna(inplace=True)
subset_data['year'] = subset_data['year'].astype(int)
recent = subset_data[subset_data['year'] >= 2016]

map_ = folium.Map(location =[40,-90], zoom_start = 2)

for i in range(len(recent)):
    lon = recent.iloc[i]['Longitude']
    lat = recent.iloc[i]['Latitude']
    month = recent.iloc[i]['month']
    year = recent.iloc[i]['year']
    fatal = recent.iloc[i]['Fatal_Bool']
    damage = recent.iloc[i]['Aircraft.Damage']
    count = recent.iloc[i]['Fatal_Counts']
    
    popup_str = "Fatal Count " + str(count)
    
    if fatal == "Unknown":
        folium.Marker([lat, lon], popup=popup_str).add_to(map_)
    if fatal == "Fatal":
        map_.simple_marker([lat, lon], popup=popup_str, marker_color='red', marker_icon='remove-sign')
    if fatal == "None":
        map_.simple_marker([lat, lon], popup=popup_str, marker_color='green', marker_icon='ok-sign')
# Out:
# /Users/elizabethlarson/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/elizabethlarson/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/elizabethlarson/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:22: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
# /Users/elizabethlarson/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:24: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead

# %%
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# ** This graph pinpoints the locations of 1,214 accidents in 2016. While most of the incidents occur in the United States, we do see more green than red. When we observe the incidents outside of the U.S., there is slightly more red than green, meaning more fatalities outside of the U.S.**

# %%
# Total accidents in 2016
len(recent)
# Out:
# 1214

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **My main purpose for this data analysis was to investigate trends associated with aircraft accidents. I was surprised that most accidents occur when the weather is clear enough for pilots to navigate the plane themselves and that there are so many incidents every year. Thankfully, the number of non-fatal accidents greatly outnumbers the number of fatal accidents, and both do appear to be decreasing. One key factor that this dataset did not include was the determined cause of the accident. In the future, combining this analysis with data containing the cause of the accident could yield more impactful results as to why we are still having so many accidents.
# **
